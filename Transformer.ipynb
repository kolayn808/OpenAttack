# %% [markdown]
# <a href="https://colab.research.google.com/github/kolayn808/OpenAttack/blob/main/Transformer.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install OpenAttack
# Out:
# Collecting OpenAttack
#   Downloading OpenAttack-2.1.1-py3-none-any.whl (145 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.4/145.4 kB 3.9 MB/s eta 0:00:00
# Requirement already satisfied: nltk>=3.5 in /usr/local/lib/python3.10/dist-packages (from OpenAttack) (3.8.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from OpenAttack) (1.23.5)
# Collecting datasets (from OpenAttack)
#   Downloading datasets-2.14.5-py3-none-any.whl (519 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 519.6/519.6 kB 26.2 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from OpenAttack) (4.66.1)
# Collecting transformers>=4.0.0 (from OpenAttack)
#   Downloading transformers-4.34.0-py3-none-any.whl (7.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.7/7.7 MB 91.6 MB/s eta 0:00:00
# Requirement already satisfied: torch>=1.5.1 in /usr/local/lib/python3.10/dist-packages (from OpenAttack) (2.0.1+cu118)
# Requirement already satisfied: click in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->OpenAttack) (8.1.7)
# Requirement already satisfied: joblib in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->OpenAttack) (1.3.2)
# Requirement already satisfied: regex>=2021.8.3 in /usr/local/lib/python3.10/dist-packages (from nltk>=3.5->OpenAttack) (2023.6.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (3.12.4)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (4.5.0)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (3.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (3.1.2)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.5.1->OpenAttack) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.5.1->OpenAttack) (3.27.6)
# Requirement already satisfied: lit in /usr/local/lib/python3.10/dist-packages (from triton==2.0.0->torch>=1.5.1->OpenAttack) (17.0.2)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.0.0->OpenAttack)
#   Downloading huggingface_hub-0.18.0-py3-none-any.whl (301 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.0/302.0 kB 41.0 MB/s eta 0:00:00
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->OpenAttack) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->OpenAttack) (6.0.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers>=4.0.0->OpenAttack) (2.31.0)
# Collecting tokenizers<0.15,>=0.14 (from transformers>=4.0.0->OpenAttack)
#   Downloading tokenizers-0.14.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (3.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 103.9 MB/s eta 0:00:00
# Collecting safetensors>=0.3.1 (from transformers>=4.0.0->OpenAttack)
#   Downloading safetensors-0.4.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 63.1 MB/s eta 0:00:00
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets->OpenAttack) (9.0.0)
# Collecting dill<0.3.8,>=0.3.0 (from datasets->OpenAttack)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 15.2 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets->OpenAttack) (1.5.3)
# Collecting xxhash (from datasets->OpenAttack)
#   Downloading xxhash-3.4.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.1/194.1 kB 24.2 MB/s eta 0:00:00
# Collecting multiprocess (from datasets->OpenAttack)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.8 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<2023.9.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets->OpenAttack) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets->OpenAttack) (3.8.6)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (3.3.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (4.0.3)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (1.4.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets->OpenAttack) (1.3.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->OpenAttack) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->OpenAttack) (2.0.6)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers>=4.0.0->OpenAttack) (2023.7.22)
# Collecting huggingface-hub<1.0,>=0.16.4 (from transformers>=4.0.0->OpenAttack)
#   Downloading huggingface_hub-0.17.3-py3-none-any.whl (295 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 295.0/295.0 kB 35.4 MB/s eta 0:00:00
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.5.1->OpenAttack) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->OpenAttack) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets->OpenAttack) (2023.3.post1)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.5.1->OpenAttack) (1.3.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.8.1->pandas->datasets->OpenAttack) (1.16.0)
# Installing collected packages: xxhash, safetensors, dill, multiprocess, huggingface-hub, tokenizers, transformers, datasets, OpenAttack
# Successfully installed OpenAttack-2.1.1 datasets-2.14.5 dill-0.3.7 huggingface-hub-0.17.3 multiprocess-0.70.15 safetensors-0.4.0 tokenizers-0.14.1 transformers-4.34.0 xxhash-3.4.1

# %%
import ssl
ssl._create_default_https_context = ssl._create_unverified_context

# %%
'''
This example code illustrates adversarial attacks against a fine-tuned model from Transformers on a dataset from Datasets.
'''
import OpenAttack
import transformers
import datasets

def dataset_mapping(x):
    return {
        "x": x["sentence"],
        "y": 1 if x["label"] > 0.5 else 0,
    }

def main():
    print("Load model")
    tokenizer = transformers.AutoTokenizer.from_pretrained("echarlaix/bert-base-uncased-sst2-acc91.1-d37-hybrid")
    model = transformers.AutoModelForSequenceClassification.from_pretrained("echarlaix/bert-base-uncased-sst2-acc91.1-d37-hybrid", num_labels=2, output_hidden_states=False)
    victim = OpenAttack.classifiers.TransformersClassifier (model, tokenizer, model.bert.embeddings.word_embeddings)

    print("New Attacker")
    attacker = OpenAttack.attackers.PWWSAttacker()

    dataset = datasets.load_dataset("sst", split="train[:20]").map(function=dataset_mapping)

    print("Start attack")
    attack_eval = OpenAttack.AttackEval(attacker, victim, metrics = [
        OpenAttack.metric.EditDistance(),
        OpenAttack.metric.ModificationRate()
    ])
    attack_eval.eval(dataset, visualize=True)

if __name__ == "__main__":
    main()
# Out:
# Load model
# Downloading (…)okenizer_config.json:   0%|          | 0.00/285 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.70k [00:00<?, ?B/s]
# Downloading (…)solve/main/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/369M [00:00<?, ?B/s]
# New Attacker
# Downloading TProcess.NLTKWordNet: 100%|██████████| 10.8M/10.8M [00:00<00:00, 16.7MB/s]
# /usr/local/lib/python3.10/dist-packages/nltk/corpus/reader/wordnet.py:1183: UserWarning: The multilingual functions are not available with this Wordnet version
#   warnings.warn(
# Downloading TProcess.NLTKSentTokenizer: 100%|██████████| 162k/162k [00:00<00:00, 1.46MB/s]
# Downloading TProcess.NLTKPerceptronPosTagger: 100%|██████████| 2.53M/2.53M [00:00<00:00, 9.76MB/s]
# Downloading builder script:   0%|          | 0.00/9.13k [00:00<?, ?B/s]
# Downloading metadata:   0%|          | 0.00/5.99k [00:00<?, ?B/s]
# Downloading readme:   0%|          | 0.00/6.68k [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/6.37M [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/790k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/8544 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1101 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/2210 [00:00<?, ? examples/s]
# Map:   0%|          | 0/20 [00:00<?, ? examples/s]
# Start attack
# Sample: 1 =====================================================================
# Label: 1 (99.95%) --> 0 (99.43%)            |
#                                             |
# The Rock is destined to be the 21st Century |
# the rock is destined to be the 21st century |
#                                             |
# ' s new `` Conan '' and that he ' s going   | Running Time:            0.018666
# ' s new `` conan '' and that he ' s fail    | Query Exceeded:          no
#                                             | Victim Model Queries:    224
# to make a splash even greater than Arnold   | Levenshtein Edit Dista:  13
# to make a splash even greater than arnold   | Word Modif. Rate:        0.325
#                                             | Succeed:                 yes
# Schwarzenegger , Jean - Claud Van Damme or  |
# schwarzenegger , jean - claud van damme or  |
#                                             |
# Steven Segal .                              |
# steven segal .                              |
#                                             |
# Sample: 2 =====================================================================
# Label: 1 (99.94%) --> 0 (91.34%)            |
#                                             |
# The gorgeously elaborate continuation of `` |
# the gorgeously elaborate continuation of `` |
#                                             |
# The Lord of the Rings '' trilogy is so      |
# the lord of the rings '' trilogy is so      |
#                                             | Running Time:            0.018481
# huge           that a column of words  can  | Query Exceeded:          no
# brobdingnagian that a column of dustup can  | Victim Model Queries:    256
#                                             | Levenshtein Edit Dista:  15
# not adequately describe  co - writer \/     | Word Modif. Rate:        0.3
# not adequately delineate co - writer \/     | Succeed:                 yes
#                                             |
# director Peter Jackson ' s expanded vision  |
# director peter jackson ' s expanded vision  |
#                                             |
# of J . R . R . Tolkien ' s Middle - earth . |
# of j . r . r . tolkien ' s middle - dry   . |
#                                             |
# Sample: 3 =====================================================================
# Label: 1 (99.83%) --> 0 (96.52%)            |
#                                             |
# Singer \/ composer Bryan Adams contributes  |
# singer \/ composer bryan adams contributes  |
#                                             |
# a slew of songs -- a few potential hits , a | Running Time:            0.012929
# a slew of songs -- a few potential hits , a | Query Exceeded:          no
#                                             | Victim Model Queries:    206
# few more simply intrusive to the story --   | Levenshtein Edit Dista:  4
# few more simply intrusive to the story --   | Word Modif. Rate:        0.097561
#                                             | Succeed:                 yes
# but the whole package certainly captures    |
# but the whole package certainly bewitch     |
#                                             |
# the intended , er , spirit of the piece .   |
# the intended , er , spirit of the piece .   |
#                                             |
# Sample: 4 =====================================================================
# Label: 0 (85.95%) --> 1 (90.83%)            |
#                                             |
# You ' d think by now America would have had | Running Time:            0.0080881
# you ' d think by now america would have had | Query Exceeded:          no
#                                             | Victim Model Queries:    139
# enough of plucky British eccentrics with    | Levenshtein Edit Dista:  4
# enough of gutsy  british eccentrics with    | Word Modif. Rate:        0.2
#                                             | Succeed:                 yes
# hearts of gold .                            |
# hearts of gold .                            |
#                                             |
# Sample: 5 =====================================================================
# Label: 1 (99.93%) --> 0 (99.29%)            |
#                                             | Running Time:            0.0046425
#                                             | Query Exceeded:          no
# Yet the act is still charming here .        | Victim Model Queries:    66
# yet the act is still tempt    here .        | Levenshtein Edit Dista:  2
#                                             | Word Modif. Rate:        0.25
#                                             | Succeed:                 yes
#                                             |
# Sample: 6 =====================================================================
# Label: 1 (99.95%) --> Failed!               |
#                                             | Running Time:            0.010023
# Whether or not you ' re enlightened by any  | Query Exceeded:          no
# of Derrida ' s lectures on `` the other ''  | Victim Model Queries:    113
# and `` the self , '' Derrida is an          | Succeed:                 no
# undeniably fascinating and playful fellow . |
#                                             |
# Sample: 7 =====================================================================
# Label: 1 (99.91%) --> 0 (97.44%)            |
#                                             |
# Just the labour involved in creating the    |
# just the labour involved in creating the    |
#                                             | Running Time:            0.011975
# layered richness of the imagery in this     | Query Exceeded:          no
# layered richness of the imagery in this     | Victim Model Queries:    119
#                                             | Levenshtein Edit Dista:  3
# chiaroscuro of madness     and light is     | Word Modif. Rate:        0.13636
# chiaroscuro of foolishness and light is     | Succeed:                 yes
#                                             |
# astonishing .                               |
# astound     .                               |
#                                             |
# Sample: 8 =====================================================================
# Label: 1 (99.94%) --> 0 (80.82%)            |
#                                             |
# Part    of the charm of Satin Rouge is that | Running Time:            0.0094967
# parting of the spell of satin rouge is that | Query Exceeded:          no
#                                             | Victim Model Queries:    91
# it avoids the obvious with humour and       | Levenshtein Edit Dista:  5
# it void   the obvious with humour and       | Word Modif. Rate:        0.27778
#                                             | Succeed:                 yes
# lightness .                                 |
# lightness .                                 |
#                                             |
# Sample: 9 =====================================================================
# Label: 1 (99.83%) --> Failed!               |
#                                             | Running Time:            0.0033519
# a screenplay more ingeniously constructed   | Query Exceeded:          no
# than `` Memento ''                          | Victim Model Queries:    29
#                                             | Succeed:                 no
#                                             |
# Sample: 10 ====================================================================
# Label: 1 (99.91%) --> Failed!               |
#                                             | Running Time:            0.0029547
#                                             | Query Exceeded:          no
# `` Extreme Ops '' exceeds expectations .    | Victim Model Queries:    27
#                                             | Succeed:                 no
#                                             |
# Sample: 11 ====================================================================
# Label: 1 (99.97%) --> 0 (97.73%)            |
#                                             |
# Good     fun       , good     action ,      | Running Time:            0.014793
# unspoilt merriment , unspoilt action ,      | Query Exceeded:          no
#                                             | Victim Model Queries:    245
# good     acting , good dialogue , good      | Levenshtein Edit Dista:  6
# unspoilt acting , good dialogue , unspoilt  | Word Modif. Rate:        0.33333
#                                             | Succeed:                 yes
# pace , good     cinematography .            |
# pace , unspoilt cinematography .            |
#                                             |
# Sample: 12 ====================================================================
# Label: 1 (81.87%) --> 0 (97.00%)            |
#                                             |
# You Should Pay Nine Bucks for This :        |
# you should pay nine bucks for this :        |
#                                             | Running Time:            0.0064118
# Because you can hear about suffering Afghan | Query Exceeded:          no
# because you can hear about suffering afghan | Victim Model Queries:    97
#                                             | Levenshtein Edit Dista:  9
# refugees on the news and still   be         | Word Modif. Rate:        0.375
# refugees on the news and however be         | Succeed:                 yes
#                                             |
# unaffected .                                |
# unaffected .                                |
#                                             |
# Sample: 13 ====================================================================
# Label: 1 (99.91%) --> 0 (99.69%)            |
#                                             | Running Time:            0.0023613
#                                             | Query Exceeded:          no
# Dramas like this make it human .            | Victim Model Queries:    74
# dramas like this crap it human .            | Levenshtein Edit Dista:  2
#                                             | Word Modif. Rate:        0.28571
#                                             | Succeed:                 yes
#                                             |
# Sample: 14 ====================================================================
# Label: 0 (99.13%) --> Failed!               |
#                                             | Running Time:            0.0078206
# A thunderous ride at first , quiet cadences | Query Exceeded:          no
# of pure finesse are few and far between ;   | Victim Model Queries:    126
# their shortage dilutes the potency of       | Succeed:                 no
# otherwise respectable action .              |
#                                             |
# Sample: 15 ====================================================================
# Label: 1 (99.97%) --> Failed!               |
#                                             | Running Time:            0.0044818
# Still , this flick is fun , and host to     | Query Exceeded:          no
# some truly excellent sequences .            | Victim Model Queries:    72
#                                             | Succeed:                 no
#                                             |
# Sample: 16 ====================================================================
# Label: 1 (99.95%) --> 0 (99.48%)            |
#                                             |
# Australian actor \/ director John   Polson  |
# australian actor \/ director toilet polson  |
#                                             |
# and award - winning English cinematographer | Running Time:            0.0091681
# and award - winning english cinematographer | Query Exceeded:          no
#                                             | Victim Model Queries:    199
# Giles Nuttgens make a terrific   effort at  | Levenshtein Edit Dista:  9
# giles nuttgens crap a terrifying effort at  | Word Modif. Rate:        0.33333
#                                             | Succeed:                 yes
# disguising the obvious with energy     and  |
# disguising the obvious with department and  |
#                                             |
# innovation .                                |
# innovation .                                |
#                                             |
# Sample: 17 ====================================================================
# Label: 1 (99.22%) --> 0 (91.40%)            |
#                                             |
# You walk out of The Good Girl with mixed    |
# you walk out of the good girl with mixed    |
#                                             | Running Time:            0.0068033
# emotions -- disapproval of Justine combined | Query Exceeded:          no
# emotions -- disapproval of justine combined | Victim Model Queries:    127
#                                             | Levenshtein Edit Dista:  6
# with a tinge of understanding for her       | Word Modif. Rate:        0.25
# with a tinge of infer         for her       | Succeed:                 yes
#                                             |
# actions .                                   |
# actions .                                   |
#                                             |
# Sample: 18 ====================================================================
# Label: 0 (99.80%) --> Failed!               |
#                                             | Running Time:            0.0084314
# Post 9 \/ 11 the philosophical message of   | Query Exceeded:          no
# `` Personal Freedom First '' might not be   | Victim Model Queries:    82
# as palatable as intended .                  | Succeed:                 no
#                                             |
# Sample: 19 ====================================================================
# Label: 1 (99.96%) --> 0 (99.66%)            |
#                                             | Running Time:            0.0067019
#                                             | Query Exceeded:          no
# Absorbing character study by André Turpin . | Victim Model Queries:    58
# suck      character study by andré turpin . | Levenshtein Edit Dista:  3
#                                             | Word Modif. Rate:        0.42857
#                                             | Succeed:                 yes
#                                             |
# Sample: 20 ====================================================================
# Label: 1 (99.85%) --> 0 (96.36%)            |
#                                             | Running Time:            0.0099037
# If you love reading and \/ or poetry , then | Query Exceeded:          no
# if you love reading and \/ or poetry , then | Victim Model Queries:    104
#                                             | Levenshtein Edit Dista:  2
# by all means check  it out .                | Word Modif. Rate:        0.11765
# by all means retard it out .                | Succeed:                 yes
#                                             |
# +=============================================+
# |                   Summary                   |
# +=============================================+
# | Total Attacked Instances:       | 20        |
# | Successful Instances:           | 14        |
# | Attack Success Rate:            | 0.7       |
# | Avg. Running Time:              | 0.0088742 |
# | Total Query Exceeded:           | 0         |
# | Avg. Victim Model Queries:      | 122.7     |
# | Avg. Levenshtein Edit Distance: | 5.9286    |
# | Avg. Word Modif. Rate:          | 0.26502   |
# +=============================================+
